# %% [markdown]
# # 데이터 생성

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
! pip install seaborn
# Out:
# Requirement already satisfied: seaborn in d:\anaconda3\envs\youn\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\anaconda3\envs\youn\lib\site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: pandas>=1.2 in d:\anaconda3\envs\youn\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\anaconda3\envs\youn\lib\site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda3\envs\youn\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda3\envs\youn\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda3\envs\youn\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda3\envs\youn\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\envs\youn\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in d:\anaconda3\envs\youn\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in d:\anaconda3\envs\youn\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda3\envs\youn\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\envs\youn\lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda3\envs\youn\lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\youn\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
np.random.seed(42)

# 날짜 생성(2025-01-01 ~ 2025-12-31)
dates = pd.date_range('2025-01-01', '2025-12-31')

regions = ['서울','부산','대구','광중','인천',]
products = ['A','B','C','D']

# 가상의 매출 데이터 생성
data = {
    'date': np.random.choice(dates, 1000),
    'region': np.random.choice(regions, 1000),
    'product': np.random.choice(products, 1000),
    'sales': np.random.randint(100, 1000, 1000),     # 매출 100 ~ 1000만원
    'profit': np.random.randint(10, 200, 1000)     # 이익 10 ~ 200만원
}

# DataFrame 생성
df = pd.DataFrame(data)

# csv 저장
df.to_csv('./data/sales_data.csv', index=False, encoding='utf-8-sig')

print("sales_data.csv 파일이 생성됐습니다.")
print(df.head())
# Out:
# sales_data.csv 파일이 생성됐습니다.
#         date region product  sales  profit
# 0 2025-04-13     대구       A    891     127
# 1 2025-12-15     대구       A    412      62
# 2 2025-09-28     서울       A    711      48
# 3 2025-04-17     부산       A    937      74
# 4 2025-03-13     부산       D    908     154

# %% [markdown]
# # csv 파일 읽어오기

# %%
df = pd.read_csv('./data/sales_data.csv')
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#         date region product  sales  profit
# 0 2025-04-13     대구       A    891     127
# 1 2025-12-15     대구       A    412      62
# 2 2025-09-28     서울       A    711      48
# 3 2025-04-17     부산       A    937      74
# 4 2025-03-13     부산       D    908     154

# %% [markdown]
# # 총 매출액 분포(단일 변수 분포 확인)

# %%
from matplotlib import font_manager, rc

# 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'   # 한글 폰트 지정
plt.rcParams['axes.unicode_minus'] = False      # 마니어스 부호 깨짐 방지

plt.figure(figsize=(8,5))
sns.histplot(df['sales'], bins=20, kde=True, color='royalblue')
plt.title('매출액 분포 (histogram)')
plt.xlabel('매출액(만원)')
plt.ylabel('빈도수')

plt.figure(figsize=(6,4))
sns.boxplot(y='sales', data=df, color='lightgreen')
plt.title('매출액 분포 (boxplot)')
plt.show()

# %% [markdown]
# # 월 별 총 매출 추세 (시간 순서)

# %%
# date를 datetime 형식으로 변환
df['date'] = pd.to_datetime(df['date'])

# 월 단위 매출 집계
df_month = df.groupby(df['date'].dt.to_period('M')).sum(numeric_only=True)
df_month.index = df_month.index.astype(str)

# 그래프 크기 및 스타일 설정
plt.figure(figsize=(10,5))

# 선 그래프 생성
plt.plot(df_month.index, df_month['sales'], marker='o', color='royalblue')

# 그래프 제목, 축이름, 격자 설정
plt.title('월 병 총 매출 추세', fontsize=14)
plt.xlabel('월', fontsize=12)
plt.ylabel('매출액', fontsize=12)
plt.grid(True)   # 격자 표시

# x축 눈금 라벨 회전
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 지역별 평균 매출 비교 (범주형 비교)

# %%
region_sales = df.groupby('region')['sales'].sum()
colors = plt.cm.Pastel1(np.linspace(0,1,len(region_sales)))

fig, ax = plt.subplots(figsize=(7,7))
wedges, texts, autotexts = ax.pie(
    region_sales,
    labels = region_sales.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=colors,
    pctdistance=0.8,
    wedgeprops=dict(width=0.4, edgecolor='w')  # 도넛 모양
)

ax.se_title('지역별 총 매출 비중', fontsize=14, fontweight='bold')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 15
#       4 fig, ax = plt.subplots(figsize=(7,7))
#       5 wedges, texts, autotexts = ax.pie(
#       6     region_sales,
#       7     labels = region_sales.index,
#    (...)
#      12     wedgeprops=dict(width=0.4, edgecolor='w')  # 도넛 모양
#      13 )
# ---> 15 ax.se_title('지역별 총 매출 비중', fontsize=14, fontweight='bold')
#      16 plt.show()
#
# AttributeError: 'Axes' object has no attribute 'se_title'

# %% [markdown]
# # 제품별 매출 - 이익 상관관계 (두 변수 관계)

# %%
plt.figure(figsize=(8,6))
scatter = plt.scatter(df['sales'], df['profit'],
                     c=df['sales'], cmap='viridis',
                     s=60, alpha=0.7, edgecolor='black')

plt.colorbar(scatter, label='매출액(만원)')
plt.title('매출 vs 이익 관계', fontsize=14, fontweight='bold')
plt.xlabel('매출액')
plt.ylabel('이익(만원)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # 지역별 월간 매출 추세 (plotly 대화형 그래프)

# %%
! pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-6.7.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-2.21.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: packaging in d:\anaconda3\envs\youn\lib\site-packages (from plotly) (26.0)
# Downloading plotly-6.7.0-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------  9.7/9.9 MB 66.9 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 66.9 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 19.9 MB/s  0:00:00
# Downloading narwhals-2.21.2-py3-none-any.whl (451 kB)
# Installing collected packages: narwhals, plotly
#
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    ---------------------------------------- 0/2 [narwhals]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    -------------------- ------------------- 1/2 [plotly]
#    ---------------------------------------- 2/2 [plotly]
#
# Successfully installed narwhals-2.21.2 plotly-6.7.0

# %%
import plotly.express as px

# %%
! pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: jinja2>=2.9 in d:\anaconda3\envs\youn\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in d:\anaconda3\envs\youn\lib\site-packages (from folium) (2.2.6)
# Requirement already satisfied: requests in d:\anaconda3\envs\youn\lib\site-packages (from folium) (2.33.1)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2026.3.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\envs\youn\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda3\envs\youn\lib\site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\youn\lib\site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\anaconda3\envs\youn\lib\site-packages (from requests->folium) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in d:\anaconda3\envs\youn\lib\site-packages (from requests->folium) (2026.5.20)
# Downloading folium-0.20.0-py2.py3-none-any.whl (113 kB)
# Downloading branca-0.8.2-py3-none-any.whl (26 kB)
# Downloading xyzservices-2026.3.0-py3-none-any.whl (94 kB)
# Installing collected packages: xyzservices, branca, folium
#
#    ------------- -------------------------- 1/3 [branca]
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    -------------------------- ------------- 2/3 [folium]
#    ---------------------------------------- 3/3 [folium]
#
# Successfully installed branca-0.8.2 folium-0.20.0 xyzservices-2026.3.0

# %%
# 월별 + 지역별 총 매출
df['month'] = df['date'].dt.strftime('%Y-%m')
df_month_region = df.groupby(['month','region'])['sales'].sum().reset_index()

# Plotly 그래프
fig = px.line(
    df_month_region,
    x='month',
    y='sales',
    color='region',
    title='지역별 월간 매출 추세',
    markers=True
)

fig.update_layout(
    xaxis_title='월',
    yaxis_title='매출액(만원)',
    legend_title='지역'
)
fig.show()
