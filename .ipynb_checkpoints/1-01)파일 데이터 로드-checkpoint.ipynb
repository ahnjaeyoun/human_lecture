# %%
# %matplotlib inline
import pandas as pd
import numpy as np
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # numpy로 파일 읽어오기

# %%
data = np.genfromtxt('./data/movies)

# %%
pip install --upgrade matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
